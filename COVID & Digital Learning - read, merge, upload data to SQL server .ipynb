# %%
import glob
import pandas as pd
import numpy as np

# %%
# upload data
district = pd.read_csv('districts_info.csv')
product = pd.read_csv('products_info.csv')
path = '/Downloads/learnplatform-covid19-impact-on-digital-learning/engagement_data' 

all_files = glob.glob(path + "/*.csv")

engagement_data = []

for filename in all_files:
    district_data = pd.read_csv(filename, index_col=None, header=0)
    district_id = filename.split("/")[6].split(".")[0]
    district_data["district_id"] = district_id
    engagement_data.append(district_data)
    
engagement_df = pd.concat(engagement_data)
engagement_df["district_id"] = engagement_df["district_id"].astype(int)

# %%
district.head(3)
# Out:
#    district_id     state  locale pct_black/hispanic pct_free/reduced  \
# 0         8815  Illinois  Suburb           [0, 0.2[         [0, 0.2[
# 1         2685       NaN     NaN                NaN              NaN
# 2         4921      Utah  Suburb           [0, 0.2[       [0.2, 0.4[
#
#   county_connections_ratio    pp_total_raw
# 0                [0.18, 1[  [14000, 16000[
# 1                      NaN             NaN
# 2                [0.18, 1[    [6000, 8000[

# %%
district.shape
# Out:
# (233, 7)

# %%
product.head(3)
# Out:
#    LP ID                         URL  Product Name  Provider/Company Name  \
# 0  13117  https://www.splashmath.com   SplashLearn          StudyPad Inc.
# 1  66933        https://abcmouse.com  ABCmouse.com  Age of Learning, Inc
# 2  50479       https://www.abcya.com        ABCya!         ABCya.com, LLC
#
#   Sector(s)                         Primary Essential Function
# 0   PreK-12                    LC - Digital Learning Platforms
# 1   PreK-12                    LC - Digital Learning Platforms
# 2   PreK-12  LC - Sites, Resources & Reference - Games & Si...

# %%
product.shape
# Out:
# (372, 6)

# %%
product['Primary Essential Function'].unique()
# Out:
# array(['LC - Digital Learning Platforms',
#        'LC - Sites, Resources & Reference - Games & Simulations',
#        'LC - Courseware & Textbooks', 'LC - Study Tools - Q&A',
#        'LC - Sites, Resources & Reference - Streaming Services',
#        'LC - Study Tools',
#        'CM - Teacher Resources - Professional Learning',
#        'SDO - Learning Management Systems (LMS)',
#        'LC - Content Creation & Curation',
#        'LC - Sites, Resources & Reference',
#        'LC - Online Course Providers & Technical Skills Development',
#        'CM - Classroom Engagement & Instruction - Communication & Messaging',
#        'SDO - School Management Software - SSO',
#        'LC - Sites, Resources & Reference - Thesaurus & Dictionary',
#        'LC/CM/SDO - Other', 'SDO - Data, Analytics & Reporting',
#        'LC - Sites, Resources & Reference - Encyclopedia',
#        'CM - Classroom Engagement & Instruction - Classroom Management',
#        'LC - Sites, Resources & Reference - Digital Collection & Repository',
#        'CM - Classroom Engagement & Instruction - Assessment & Classroom Response',
#        'CM - Virtual Classroom - Video Conferencing & Screen Sharing',
#        'SDO - Data, Analytics & Reporting - Site Hosting & Data Warehousing',
#        nan,
#        'SDO - Data, Analytics & Reporting - Student Information Systems (SIS)',
#        'LC - Career Planning & Job Search', 'SDO - Human Resources',
#        'SDO - School Management Software - Mobile Device Management',
#        'CM - Teacher Resources - Grading & Attendance',
#        'LC - Study Tools - Tutoring',
#        'SDO - Large-Scale & Standardized Testing',
#        'CM - Teacher Resources - Lesson Planning',
#        'LC - Sites, Resources & References - Learning Materials & Supplies',
#        'SDO - Admissions, Enrollment & Rostering',
#        'LC - Study Tools - Test Prep & Study Skills',
#        'SDO - Environmental, Health & Safety (EHS) Compliance',
#        'SDO - Other'], dtype=object)

# %%
# Nans 
product['Primary Essential Function'] = product['Primary Essential Function'].fillna('LC/CM/SDO - Other')

# %%
# editing Primary Essential Function
product['PS_function_main'] = product['Primary Essential Function'].apply(lambda x: x.split(' - ')[0] if x == x else x)
product['PS_function_sub'] = product['Primary Essential Function'].apply(lambda x: x.split(' - ')[1] if x == x else x)

# Synchronize similar values
product['PS_function_sub'] = product['PS_function_sub'].replace({'Sites, Resources & References' : 'Sites, Resources & Reference'})
product.drop("Primary Essential Function", axis=1, inplace=True)

# %% [markdown]
# * LC = Learning & Curriculum
# * CM = Classroom Management
# * SDO = School & District Operations

# %%
product['PS_function_main'].unique()
# Out:
# array(['LC', 'CM', 'SDO', 'LC/CM/SDO'], dtype=object)

# %%
product['PS_function_sub'].unique()
# Out:
# array(['Digital Learning Platforms', 'Sites, Resources & Reference',
#        'Courseware & Textbooks', 'Study Tools', 'Teacher Resources',
#        'Learning Management Systems (LMS)', 'Content Creation & Curation',
#        'Online Course Providers & Technical Skills Development',
#        'Classroom Engagement & Instruction', 'School Management Software',
#        'Other', 'Data, Analytics & Reporting', 'Virtual Classroom',
#        'Career Planning & Job Search', 'Human Resources',
#        'Large-Scale & Standardized Testing',
#        'Admissions, Enrollment & Rostering',
#        'Environmental, Health & Safety (EHS) Compliance'], dtype=object)

# %%
# adding fillters by Sectors 
sector = product['Sector(s)'].str.get_dummies(sep="; ")

# %%
full_product = product.merge(sector, left_index = True, right_index = True)

# %%
full_product = full_product.drop(columns = ['Sector(s)'])

# %%
full_product.head(3)
# Out:
#    LP ID                         URL  Product Name  Provider/Company Name  \
# 0  13117  https://www.splashmath.com   SplashLearn          StudyPad Inc.
# 1  66933        https://abcmouse.com  ABCmouse.com  Age of Learning, Inc
# 2  50479       https://www.abcya.com        ABCya!         ABCya.com, LLC
#
#   PS_function_main               PS_function_sub  Corporate  Higher Ed  \
# 0               LC    Digital Learning Platforms          0          0
# 1               LC    Digital Learning Platforms          0          0
# 2               LC  Sites, Resources & Reference          0          0
#
#    PreK-12
# 0        1
# 1        1
# 2        1

# %%
engagement_df.head(3)
# Out:
#          time    lp_id  pct_access  engagement_index  district_id
# 0  2020-01-01  29322.0        0.04              1.30         3188
# 1  2020-01-01  57084.0        0.04              0.43         3188
# 2  2020-01-01  99916.0        0.09              5.20         3188

# %%
# Where are Null values?
engagement_df.isnull().sum()
# Out:
# time                      0
# lp_id                   541
# pct_access            13447
# engagement_index    5378409
# district_id               0
# dtype: int64

# %%
# Data has 22 million rows
engagement_df.shape
# Out:
# (22324190, 5)

# %%
# Merge all data sets together except data where is no any valuable information.
engagement_districts_merged = pd.merge(engagement_df, district,how="left", on="district_id")
engagement_districts_products_merged = pd.merge(engagement_districts_merged, full_product, how="left", left_on="lp_id", right_on="LP ID")

# Dropping all engagement info without a state
engagement = engagement_districts_products_merged[engagement_districts_products_merged["state"].notnull() & engagement_districts_products_merged["LP ID"].notnull()]

# %%
engagement.head(20)
# Out:
#              time    lp_id  pct_access  engagement_index  district_id  \
# 67430  2020-01-01  32213.0        0.41             18.49         7305
# 67431  2020-01-01  51340.0        0.07              6.85         7305
# 67432  2020-01-01  49062.0        0.07              6.16         7305
# 67433  2020-01-01  99916.0        0.41             10.27         7305
# 67434  2020-01-01  95731.0        0.68             47.26         7305
# 67435  2020-01-01  76649.0        0.00               NaN         7305
# 67436  2020-01-01  69863.0        0.07              2.74         7305
# 67437  2020-01-01  11206.0        0.07              0.68         7305
# 67438  2020-01-01  64998.0        0.00               NaN         7305
# 67439  2020-01-01  80144.0        0.07              0.68         7305
# 67440  2020-01-01  28504.0        0.00               NaN         7305
# 67441  2020-01-01  36620.0        0.07             19.18         7305
# 67442  2020-01-01  90153.0        0.21              3.42         7305
# 67443  2020-01-01  47267.0        0.00               NaN         7305
# 67444  2020-01-01  92918.0        0.07              0.68         7305
# 67445  2020-01-01  64947.0        0.07              3.42         7305
# 67448  2020-01-02  83862.0        0.00               NaN         7305
# 67449  2020-01-02  83270.0        0.14              2.05         7305
# 67450  2020-01-02  69429.0        0.00               NaN         7305
# 67453  2020-01-02  60051.0        0.00               NaN         7305
#
#                state  locale pct_black/hispanic pct_free/reduced  \
# 67430  Massachusetts  Suburb           [0, 0.2[              NaN
# 67431  Massachusetts  Suburb           [0, 0.2[              NaN
# 67432  Massachusetts  Suburb           [0, 0.2[              NaN
# 67433  Massachusetts  Suburb           [0, 0.2[              NaN
# 67434  Massachusetts  Suburb           [0, 0.2[              NaN
# 67435  Massachusetts  Suburb           [0, 0.2[              NaN
# 67436  Massachusetts  Suburb           [0, 0.2[              NaN
# 67437  Massachusetts  Suburb           [0, 0.2[              NaN
# 67438  Massachusetts  Suburb           [0, 0.2[              NaN
# 67439  Massachusetts  Suburb           [0, 0.2[              NaN
# 67440  Massachusetts  Suburb           [0, 0.2[              NaN
# 67441  Massachusetts  Suburb           [0, 0.2[              NaN
# 67442  Massachusetts  Suburb           [0, 0.2[              NaN
# 67443  Massachusetts  Suburb           [0, 0.2[              NaN
# 67444  Massachusetts  Suburb           [0, 0.2[              NaN
# 67445  Massachusetts  Suburb           [0, 0.2[              NaN
# 67448  Massachusetts  Suburb           [0, 0.2[              NaN
# 67449  Massachusetts  Suburb           [0, 0.2[              NaN
# 67450  Massachusetts  Suburb           [0, 0.2[              NaN
# 67453  Massachusetts  Suburb           [0, 0.2[              NaN
#
#       county_connections_ratio    pp_total_raw    LP ID  \
# 67430                [0.18, 1[  [14000, 16000[  32213.0
# 67431                [0.18, 1[  [14000, 16000[  51340.0
# 67432                [0.18, 1[  [14000, 16000[  49062.0
# 67433                [0.18, 1[  [14000, 16000[  99916.0
# 67434                [0.18, 1[  [14000, 16000[  95731.0
# 67435                [0.18, 1[  [14000, 16000[  76649.0
# 67436                [0.18, 1[  [14000, 16000[  69863.0
# 67437                [0.18, 1[  [14000, 16000[  11206.0
# 67438                [0.18, 1[  [14000, 16000[  64998.0
# 67439                [0.18, 1[  [14000, 16000[  80144.0
# 67440                [0.18, 1[  [14000, 16000[  28504.0
# 67441                [0.18, 1[  [14000, 16000[  36620.0
# 67442                [0.18, 1[  [14000, 16000[  90153.0
# 67443                [0.18, 1[  [14000, 16000[  47267.0
# 67444                [0.18, 1[  [14000, 16000[  92918.0
# 67445                [0.18, 1[  [14000, 16000[  64947.0
# 67448                [0.18, 1[  [14000, 16000[  83862.0
# 67449                [0.18, 1[  [14000, 16000[  83270.0
# 67450                [0.18, 1[  [14000, 16000[  69429.0
# 67453                [0.18, 1[  [14000, 16000[  60051.0
#
#                                               URL           Product Name  \
# 67430                https://classroom.google.com       Google Classroom
# 67431                  https://www.grammarly.com/              Grammarly
# 67432                     http://www.quia.com/web               Quia Web
# 67433              https://drive.google.com/start           Google Drive
# 67434                     http://docs.google.com/            Google Docs
# 67435                         https://clever.com/                 Clever
# 67436          https://chrome.google.com/webstore       Chrome Web Store
# 67437                http://www.google.com/earth/           Google Earth
# 67438                      http://web.stmath.com/                ST Math
# 67439                      https://www.quora.com/                  Quora
# 67440             http://google.com/sheets/about/          Google Sheets
# 67441                 https://www.disneyplus.com/                Disney+
# 67442                    https://www.netflix.com/                Netflix
# 67443                   http://www.classdojo.com/              ClassDojo
# 67444  https://www.usnews.com/best-colleges/myfit        College Compass
# 67445                       http://www.desmos.com                 Desmos
# 67448                    http://www.raz-kids.com/               Raz-Kids
# 67449          https://artsandculture.google.com/  Google Arts & Culture
# 67450                       http://wordpress.com/              WordPress
# 67453                https://www.bigideasmath.com         Big Ideas Math
#
#                 Provider/Company Name PS_function_main  \
# 67430                      Google LLC              SDO
# 67431                       Grammarly               LC
# 67432                    IXL Learning               LC
# 67433                      Google LLC        LC/CM/SDO
# 67434                      Google LLC               LC
# 67435                          Clever              SDO
# 67436                      Google LLC        LC/CM/SDO
# 67437                      Google LLC               LC
# 67438         MIND Research Institute               LC
# 67439                           Quora               LC
# 67440                      Google LLC        LC/CM/SDO
# 67441                          Disney               LC
# 67442                         Netflix               LC
# 67443                 ClassDojo, Inc.               CM
# 67444  U.S. News & World Report, L.P.        LC/CM/SDO
# 67445                          Desmos               LC
# 67448                    Learning A-Z               LC
# 67449                      Google LLC               LC
# 67450                       WordPress              SDO
# 67453              Big Ideas Learning               LC
#
#                           PS_function_sub  Corporate  Higher Ed  PreK-12
# 67430   Learning Management Systems (LMS)        1.0        1.0      1.0
# 67431                         Study Tools        1.0        1.0      1.0
# 67432          Digital Learning Platforms        0.0        0.0      1.0
# 67433                               Other        1.0        1.0      1.0
# 67434         Content Creation & Curation        1.0        1.0      1.0
# 67435          School Management Software        0.0        0.0      1.0
# 67436                               Other        1.0        1.0      1.0
# 67437        Sites, Resources & Reference        1.0        1.0      1.0
# 67438          Digital Learning Platforms        0.0        0.0      1.0
# 67439                         Study Tools        1.0        1.0      1.0
# 67440                               Other        1.0        1.0      1.0
# 67441        Sites, Resources & Reference        0.0        1.0      1.0
# 67442        Sites, Resources & Reference        1.0        1.0      1.0
# 67443  Classroom Engagement & Instruction        0.0        0.0      1.0
# 67444                               Other        0.0        0.0      0.0
# 67445                         Study Tools        0.0        1.0      1.0
# 67448          Digital Learning Platforms        0.0        0.0      1.0
# 67449        Sites, Resources & Reference        0.0        1.0      1.0
# 67450         Data, Analytics & Reporting        1.0        1.0      1.0
# 67453              Courseware & Textbooks        0.0        0.0      1.0

# %%
# Checking the Null values
engagement.isnull().sum()
# Out:
# time                              0
# lp_id                             0
# pct_access                     5846
# engagement_index            1825936
# district_id                       0
# state                             0
# locale                            0
# pct_black/hispanic                0
# pct_free/reduced            1387433
# county_connections_ratio     755602
# pp_total_raw                2900755
# LP ID                             0
# URL                               0
# Product Name                      0
# Provider/Company Name             0
# PS_function_main                  0
# PS_function_sub                   0
# Corporate                         0
# Higher Ed                         0
# PreK-12                           0
# dtype: int64

# %%
# Finally data has 9 million rows
engagement.shape
# Out:
# (9139701, 20)

# %%
# editing a columns names
engagement = engagement.drop(columns = ['LP ID'])

# %%
engagement = engagement.rename(columns = str.lower)

# %%
engagement.columns = engagement.columns.str.replace('/','_')

# %%
engagement.columns = engagement.columns.str.replace(' ','_')

# %%
engagement.columns = engagement.columns.str.replace('-','_')

# %%
engagement.head(3)
# Out:
#              time    lp_id  pct_access  engagement_index  district_id  \
# 67430  2020-01-01  32213.0        0.41             18.49         7305
# 67431  2020-01-01  51340.0        0.07              6.85         7305
# 67432  2020-01-01  49062.0        0.07              6.16         7305
#
#                state  locale pct_black_hispanic pct_free_reduced  \
# 67430  Massachusetts  Suburb           [0, 0.2[              NaN
# 67431  Massachusetts  Suburb           [0, 0.2[              NaN
# 67432  Massachusetts  Suburb           [0, 0.2[              NaN
#
#       county_connections_ratio    pp_total_raw                           url  \
# 67430                [0.18, 1[  [14000, 16000[  https://classroom.google.com
# 67431                [0.18, 1[  [14000, 16000[    https://www.grammarly.com/
# 67432                [0.18, 1[  [14000, 16000[       http://www.quia.com/web
#
#            product_name provider_company_name ps_function_main  \
# 67430  Google Classroom            Google LLC              SDO
# 67431         Grammarly             Grammarly               LC
# 67432          Quia Web          IXL Learning               LC
#
#                          ps_function_sub  corporate  higher_ed  prek_12
# 67430  Learning Management Systems (LMS)        1.0        1.0      1.0
# 67431                        Study Tools        1.0        1.0      1.0
# 67432         Digital Learning Platforms        0.0        0.0      1.0

# %%
engagement.dtypes
# Out:
# time                         object
# lp_id                       float64
# pct_access                  float64
# engagement_index            float64
# district_id                   int64
# state                        object
# locale                       object
# pct_black_hispanic           object
# pct_free_reduced             object
# county_connections_ratio     object
# pp_total_raw                 object
# url                          object
# product_name                 object
# provider_company_name        object
# ps_function_main             object
# ps_function_sub              object
# corporate                   float64
# higher_ed                   float64
# prek_12                     float64
# dtype: object

# %%
# data types 
engagement['lp_id'] = engagement['lp_id'].astype(int)

# %%
engagement[['corporate','higher_ed','prek_12']] = engagement[['corporate','higher_ed','prek_12']].astype(int)

# %%
# CSV_file 
engagement.to_csv('engagemen_full.csv')

# %%
# Upload data to MySQL directly
from sqlalchemy import create_engine, types

engine = create_engine(‘mysql://root:Is04@localhost/bi_marathon_test_’) # enter your password and database names here

engagement.to_sql(‘temp_table’,con=engine,index=False,if_exists=‘append’) # Replace Table_name with your sql table name
